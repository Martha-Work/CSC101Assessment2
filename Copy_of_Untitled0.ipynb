# %% [markdown]
# <a href="https://colab.research.google.com/github/Martha-Work/CSC101Assessment2/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# contacts and phone number
Contacts = {
    "Andy": "687-0385",
    "Beyonce": "045-6799",
    "Charm": "680-4789"
}

#add key and value
Contacts["Martha"] ="578-3564"

print(Contacts)
# Out:
# {'Andy': '687-0385', 'Beyonce': '045-6799', 'Charm': '680-4789', 'Martha': '578-3564'}

# %%
contacts = {
    "Andy": "687-0385",
    "Beyonce": "045-6799",
    "Charm": "680-4789",
    "Martha": "578-3564"
}

# update an existing contact
contacts["Beyonce"] = "999-1234"

print(contacts)
# Out:
# {'Andy': '687-0385', 'Beyonce': '999-1234', 'Charm': '680-4789', 'Martha': '578-3564'}

# %%
contacts = {
    "Andy": "687-0385",
    "Beyonce": "045-6799",
    "Charm": "680-4789",
    "Martha": "578-3564"
}
for name in contacts:
    print(name, contacts[name])
# Out:
# Andy 687-0385
# Beyonce 045-6799
# Charm 680-4789
# Martha 578-3564

# %%
contacts = {
    "Andy": {
        "phone": "687-0385",
        "email": "andy@gmail.com"
    },
    "Beyonce": {
        "phone": "045-6799",
        "email": "beyonce@gmail.com"
    },
    "Charm": {
        "phone": "680-4789",
        "email": "charm@gmail.com"
    },
    "Martha": {
        "phone": "578-3564",
        "email": "martha@gmail.com"
    }
}

for name in contacts:
    print(name, contacts[name]["phone"], contacts[name]["email"])
# Out:
# Andy 687-0385 andy@gmail.com
# Beyonce 045-6799 beyonce@gmail.com
# Charm 680-4789 charm@gmail.com
# Martha 578-3564 martha@gmail.com
